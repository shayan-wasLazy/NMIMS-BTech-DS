# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv(r"D:\collage\sem 8\ssdi\Auto.csv").dropna()

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %%
# Target mpg

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)
df.columns

#cat: cylinders, orgin
#cont: 'displacement', 'horsepower', 'weight','acceleration'
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
df["horsepower"] = pd.to_numeric(df["horsepower"], errors="coerce")

# %%
scaler = StandardScaler()
df[['displacement', 'horsepower', 'weight','acceleration']] = scaler.fit_transform(df[['displacement', 'horsepower', 'weight','acceleration']])

# %%
# get dummies on cats

df = pd.get_dummies(df, columns=["cylinders", "origin"], drop_first=True)

# %%
df
# Out:
#       mpg  displacement  horsepower    weight  acceleration  year  \
# 0    18.0      1.088435    0.664133  0.630274     -1.294604    70
# 1    15.0      1.500913    1.574594  0.853457     -1.476652    70
# 2    18.0      1.193953    1.184397  0.549975     -1.658700    70
# 3    16.0      1.059658    1.184397  0.546432     -1.294604    70
# 4    17.0      1.040473    0.924265  0.565326     -1.840747    70
# ..    ...           ...         ...       ...           ...   ...
# 392  27.0     -0.513513   -0.480448 -0.212865      0.016141    82
# 393  44.0     -0.925991   -1.364896 -0.992237      3.293004    82
# 394  32.0     -0.561476   -0.532474 -0.797394     -1.440242    82
# 395  28.0     -0.705363   -0.662540 -0.407708      1.108429    82
# 396  31.0     -0.714956   -0.584501 -0.295526      1.399705    82
#
#                           name  cylinders_4  cylinders_5  cylinders_6  \
# 0    chevrolet chevelle malibu        False        False        False
# 1            buick skylark 320        False        False        False
# 2           plymouth satellite        False        False        False
# 3                amc rebel sst        False        False        False
# 4                  ford torino        False        False        False
# ..                         ...          ...          ...          ...
# 392            ford mustang gl         True        False        False
# 393                  vw pickup         True        False        False
# 394              dodge rampage         True        False        False
# 395                ford ranger         True        False        False
# 396                 chevy s-10         True        False        False
#
#      cylinders_8  origin_2  origin_3
# 0           True     False     False
# 1           True     False     False
# 2           True     False     False
# 3           True     False     False
# 4           True     False     False
# ..           ...       ...       ...
# 392        False     False     False
# 393        False      True     False
# 394        False     False     False
# 395        False     False     False
# 396        False     False     False
#
# [397 rows x 13 columns]

# %%
# using vif:

x = df[[""]]
