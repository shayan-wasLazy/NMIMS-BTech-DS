# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ![tfe2wf235f4.png](attachment:f5de2337-8544-4615-a6d7-b50f83df9782.png)

# %%
#Q1c

brandA = 0.4
brandB = 0.35
brandC = 0.25
af = 0.02
bf = 0.05
cf = 0.03

d = af* brandA + bf * brandB + cf * brandC
b = brandB * bf / d
b
# Out:
# 0.5303030303030303

# %% [markdown]
# ![Screenshot 2026-05-07 164417.png](attachment:b22ae1d8-4d60-42b3-ba99-da2aae453835.png)

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

n = 150

experience = np.random.randint(1,15,n)
education = np.random.randint(1,4,n)
projects = np.random.randint(1,20,n)

salary = (
    5000 +
    experience*2500 +
    education*12000 +
    projects*1500 +
    np.random.randn(n)*10000
)

df = pd.DataFrame({
    'Experience':experience,
    'Education':education,
    'Projects':projects,
    'Salary':salary
})

# %%
df
# Out:
#      Experience  Education  Projects        Salary
# 0             7          2        16  63192.585968
# 1             4          1        17  39700.802667
# 2            13          3         2  74126.080388
# 3            11          2         1  76720.056805
# 4             8          3        16  84805.578591
# ..          ...        ...       ...           ...
# 145          12          2         1  75913.709969
# 146           2          2        16  49721.069211
# 147           1          3         7  50961.355646
# 148           7          3         5  68423.336861
# 149           7          2         3  71473.989211
#
# [150 rows x 4 columns]

# %%
import seaborn as sns

# %%
sns.regplot(x = df["Projects"], y = df["Salary"], data = df)
# Out:
# <Axes: xlabel='Projects', ylabel='Salary'>

# %%
# vif

from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

x = df[["Experience", "Education", "Projects"]]
y = df["Salary"]

x = x.astype(float)
x = add_constant(x)

vif = pd.DataFrame()
vif["Features"] = x.columns
vif["Vif"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif
# Out:
#      Features        Vif
# 0       const  16.458728
# 1  Experience   1.042690
# 2   Education   1.038184
# 3    Projects   1.004517

# %%
ridge2 = Ridge(alpha=best_alpha)
ridge2.fit(X_train,Y_train)
pred2 = ridge2.predict(X_test)
print(pd.Series(ridge2.coef_,index=X.columns))
print(mean_squared_error(Y_test,pred2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 ridge2 = Ridge(alpha=best_alpha)
#       2 ridge2.fit(X_train,Y_train)
#       3 pred2 = ridge2.predict(X_test)
#
# NameError: name 'best_alpha' is not defined
