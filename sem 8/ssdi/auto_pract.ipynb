# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns   # graphical
from sklearn.preprocessing import scale
import sklearn.linear_model as lm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm

# %%
df_auto = pd.read_csv("Auto.csv", na_values="?").dropna()

# %%
df_auto_pp = pd.get_dummies(df_auto, columns=["cylinders"])

lm_fit6 = ols("mpg ~ cylinders_4 + horsepower",df_auto_pp).fit()
lm_fit6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     454.9
# Date:                Wed, 08 Apr 2026   Prob (F-statistic):          1.47e-102
# Time:                        23:58:41   Log-Likelihood:                -1124.9
# No. Observations:                 392   AIC:                             2256.
# Df Residuals:                     389   BIC:                             2268.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %%
sns.regplot(data=df_auto, x = "horsepower", y = "mpg", order= 3)
plt.show()

# %%
df_auto["horsepower"] = df_auto["horsepower"].astype(int)

# %%
df_auto_pp
# Out:
#       mpg  displacement  horsepower  weight  acceleration  year  origin  \
# 0    18.0         307.0         130    3504          12.0    70       1
# 1    15.0         350.0         165    3693          11.5    70       1
# 2    18.0         318.0         150    3436          11.0    70       1
# 3    16.0         304.0         150    3433          12.0    70       1
# 4    17.0         302.0         140    3449          10.5    70       1
# ..    ...           ...         ...     ...           ...   ...     ...
# 392  27.0         140.0          86    2790          15.6    82       1
# 393  44.0          97.0          52    2130          24.6    82       2
# 394  32.0         135.0          84    2295          11.6    82       1
# 395  28.0         120.0          79    2625          18.6    82       1
# 396  31.0         119.0          82    2720          19.4    82       1
#
#                           name  cylinders_3  cylinders_4  cylinders_5  \
# ...

# %%
sns.pairplot(df_auto)
df_auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
df_auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object
