# %%
#Task 1:- a

s = input('Enter your sentence: ')
rs = s[::-1]
print(f"Reversed sentence: {rs}")
# Out:
# Enter your sentence: my name is shayan
# Reversed sentence: nayahs si eman ym

# %%
#Task 1:- b

a = input('Enter your string: ')
oa = a[1::2]
print(f"Odd places: {oa}")
# Out:
# Enter your string: my name is shayan
# Odd places: ynm ssaa

# %%
#Task 1:- c

x = input('Enter your string: ')
y = input('Enter your specific string: ')

if x.startswith(y) :
    print(f"{x} contains {y}")
else:
    print(f"{x} doesn't contain {y}")
# Out:
# Enter your string: shayan
# Enter your specific string: s
# shayan contains s

# %%
#Task 1:- e

Input_String= input("Enter your staring: ")
String_To_Replace = input("Enter the word to replace: ")
Replaced_Substring = input("Enter the word to be replaced by: ")

Final_String = Input_String.replace(String_To_Replace ,Replaced_Substring)
print(f"{Final_String}")
# Out:
# Enter your staring: hello I like games
# Enter the word to replace: games
# Enter the word to be replaced by: studies
# hello I like studies

# %%
#Task 1:- f

import string

str1 = ["I like,", "@games"]

swp = [''.join(char for char in s if char not in string.punctuation) for s in str1]
print(f"{swp}")
# Out:
# ['I like', 'games']

# %%
#Task 1:- g



string1 = input("Enter your first string")
string2 = input("Enter your second string")

min_lenght = min(len(string1), len(string2))
m = 0
for i in range(min_lenght):
    if string[i] == string2[i]:
        m  += 1
print(f"{m}")
# Out:
# Enter your first stringI am good
# Enter your second stringI am bad
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12744\671676303.py in <module>
#       9 m = 0
#      10 for i in range(min_lenght):
# ---> 11     if string[i] == string2[i]:
#      12         m  += 1
#      13 print(f"{m}")
#
# TypeError: 'module' object is not subscriptable

# %%
#Task 1:- h

Input_string =  input("Enter your string")
String_list = list(Input_string)
print(f"{String_list}")
# Out:
# Enter your stringHello
# ['H', 'e', 'l', 'l', 'o']

# %%
#Task 1:- i

String_list = ["123", "456", "789"]
int_list = [int(s) for s in String_list]
print(f"{int_list}")
# Out:
# [123, 456, 789]

# %%
#Task 1:- j

inputs = input("Enter a string")
up = sum(1 for char in inputs if char.isupper())
low = sum(1 for char in inputs if char.islower())
print(f"Upper: {up}")
print(f"Lower: {low}")
# Out:
# Enter a stringHelLo
# Upper: 2
# Lower: 3

# %%
#Task 1:- k

Input_string = input("Enter your string")
vowels = []
for char in Input_string:
    if char.lower() in 'aeiou':
        vowels.append(char)
print(f"{vowels}")
# Out:
# Enter your stringHello this my vowels list
# ['e', 'o', 'i', 'o', 'e', 'i']

# %%
#Task 1:- l

string_list = ["4", "5", "3", "6"]
sorted_list = sorted(string_list)
print(f"{sorted_list}")
# Out:
# ['3', '4', '5', '6']

# %%
#Task 1:- m

inputs = input("Enter your string")
print("upper case", inputs.upper())
print("lower case", inputs.lower())
# Out:
# Enter your stringHello
# upper case HELLO
# lower case hello

# %%
#Task 1:- n

ints = int(input("Enter your String: "))
strs = str(ints)
print("Converted string: ", strs)
print(type(strs))
# Out:
# Enter your String: 155465
# Converted string:  155465
# <class 'str'>

# %%
#Task 2

i = input("Enter your string: ")

r = i.replace(" ", "#")
              
print(f"original: {i}",)
print(f"final: {r}")
# Out:
# Enter your string: Hello world
# original: Hello world
# final: Hello#world

# %%
#Task 3

a = input("Enter ther first string: ")
b = input("Enter second string: ")

la = a.lower()
lb = b.lower()

wa = set(la.split())
wb = set(lb.split())

cm = wa.intersection(wb)

print(f"Words are: {cm}")
# Out:
# Enter ther first string: Hello this is my luxurious house
# Enter second string: hello this is my gamming place
# Words are: {'this', 'hello', 'my', 'is'}

# %%
#Task4

insert = input('Enter a string: ')
inputs = insert.lower()

counta = inputs.count("a")
counte = inputs.count("e")
counti = inputs.count("i")
counto = inputs.count("o")
countu = inputs.count("u")

print("Frequency is: ")
print("A/a: ", counta)
print("A/e: ", counte)
print("A/i: ", counti)
print("A/o: ", counto)
print("A/u: ", countu)
# Out:
# Enter a string: Hello this is my world
# Frequency is:
# A/a:  0
# A/e:  1
# A/i:  2
# A/o:  2
# A/u:  0

# %%
#Task 5:- a

spb = ["not just sticks"]

print(f"Initial List: {spb}")

spb.append("Soup sticks")
spb.append("Just sticks")

print(f"Final List: {spb}")
# Out:
# Initial List: ['not just sticks']
# Final List: ['not just sticks', 'Soup sticks', 'Just sticks']

# %%
#Task 5:- b and c

spb.insert(1,"Totally sticks")
print(f"Final List: {spb}")
# Out:
# Final List: ['not just sticks', 'Totally sticks', 'Soup sticks', 'Just sticks']

# %%
#Task 5:- d

spb.remove("Soup sticks")
print(f"Final List: {spb}")
# Out:
# Final List: ['not just sticks', 'Totally sticks', 'Just sticks']

# %%
#Task 5:- e

spb.clear()
print(f"Final List: {spb}")
# Out:
# Final List: []

# %%
#Task 5:- 

spb.extend(["Fish","Fish with legs", "Fish without legs"])
print(f"Current List: {spb}")
# Out:
# Current List: ['Fish', 'Fish with legs', 'Fish without legs']

# %%
#Task 5:- g

sr = spb.pop(1)
print(f"Removed Item: {sr}")
print(f"Current List: {spb}")
# Out:
# Removed Item: Fish
# Current List: ['Fish without legs']

# %%
#Task 5:- h

sf = spb.count("Fish")
print(f"Count: {sf}")
# Out:
# Count: 1

# %%
#Task 5:- i

spb.sort()
print(f"Sorted List: {spb}")
# Out:
# Sorted List: ['Fish', 'Fish without legs']

# %%
#Task 5:- j

spb.reverse()
print(f"Revered List: {spb}")
# Out:
# Revered List: ['Fish without legs', 'Fish']

# %%
#Task 6:

List2 = [1, 2, 3, 9, 4, 5, 2, 6, 7, 4, 8, 9, 75986]

uv = set(List2)

print(f"count of unique values: ")

for v in uv:
    count = List2.count(v)
    print(f"{v}: {count}")
# Out:
# count of unique values:
# 1: 1
# 2: 2
# 3: 1
# 4: 2
# 5: 1
# 6: 1
# 7: 1
# 8: 1
# 9: 2
# 75986: 1

# %%
# Task 7:

List3 = ["ad", "abc", "ab", "ac", "abc", "aa"]
uv2 = list(set(''.join(List3)))

print(f"{uv2}")
# Out:
# ['d', 'c', 'b', 'a']

# %%
# Task 8:

nos = input("Enter the list of numbers: ")
Num_List = [int(num) for num in nos.split()]
pos = 0
neg = 0

for num in Num_List:
    if num > 0:
        pos += 1
    else:
        neg += 1
        
print(f"Positive numbers: {pos}")
print(f"negative Numbers: {neg}")
# Out:
# Enter the list of numbers: 1 2 3 4 -6 5 -7
# Positive numbers: 5
# negative Numbers: 2

# %%
# Task 9:

nos2 = input("Enter the list of numbers: ")
Num_List_2 = [int(num) for num in nos.split()]
summ = 0

for num in Num_List_2:
    summ += num
    
print(f"Sum is:",summ)
# Out:
# Enter the list of numbers: 1 2
# Sum is: 2

# %%
# Task 10:

List4 = input("Enter list of words in a sentence: ").split()


val = int(input("Enter value: "))

longer_n = [word for word in List4 if len(word) > val]
print(longer_n)
# Out:
# Enter list of words in a sentence: VJBHEDVUJ BND SGHVUISHGVHVU SVHIHSVH
# Enter value: 3
# ['VJBHEDVUJ', 'SGHVUISHGVHVU', 'SVHIHSVH']

# %%
# Task 11:

List5 = ["vandal", "Phantom", "Spectre", "bulldog"]
List6 = ["vandal", "Phantom", "ghost", "P250"]

List5s6 = [gun for gun in List5 if gun not in List6]
List6s5 = [gun for gun in List6 if gun not in List5]

print(f"{List5s6}")
print(f"{List6s5}")
# Out:
# ['Spectre', 'bulldog']
# ['ghost', 'P250']

# %%
# Task 12

List7 = ["Hey", "", "blind", "man", "!"]

c_list = ""
for i in List7:
    c_list += i
    print(c_list)
# Out:
# Hey
# Hey
# Heyblind
# Heyblindman
# Heyblindman!

# %%
# Task 13

List8 = [1 ,2 , 4, 5]
v3 = input("Enter value to enter: ")

mod_list = [v3 + str(item) for item in List8]
print(mod_list)
# Out:
# Enter value to enter: hello
# ['hello1', 'hello2', 'hello4', 'hello5']

# %%
# Task 14:

List_List = [[1, 4 ,6], [2, 6, 9], [1000, 57858, 76987]]

max1 = max(List_List, key = sum)
print(max1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12840\3927965967.py in <module>
#       3 List_List = [[1, 4 ,6], [2, 6, 9], [1000, 57858, 76987]]
#       4
# ----> 5 max1 = max(List_List, key = sum)
#       6 print(max1)
#
# TypeError: 'int' object is not callable
