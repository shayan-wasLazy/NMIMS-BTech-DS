# %%
a = 3

# %%
b = 5

# %% [markdown]
# addition

# %%
sum = a + b

# %%
print(sum)
# Out:
# 8

# %% [markdown]
# subtraction

# %%
sub = b - a

# %%
print(sub)
# Out:
# 2

# %% [markdown]
# multiplication

# %%
mul = 3 * 5

# %%
print(mul)
# Out:
# 15

# %% [markdown]
# division

# %%
div = 3 / 5

# %%
print(div)
# Out:
# 0.6

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("my name is shayan\n my name starts with S")
# Out:
# my name is shayan
#  my name starts with S

# %%
print("There is a gap after this -->\tcan you see it?")
# Out:
# There is a gap after this -->	can you see it?

# %%
print(2 * "me")
# Out:
# meme

# %%
print(12 ,"December" ,2023 , sep = '. ')
# Out:
# 12. December. 2023

# %%
print(12 ,"December" ,2023 , sep = ' / ')
# Out:
# 12 / December / 2023

# %%
print("moye\t" + "moye")
# Out:
# moye	moye

# %%
x = 5
y = 5

print("The value of x is {} and the value of y is {}". format(x, y))
# Out:
# The value of x is 5 and the value of y is 5

# %%
num = input("Enter a number: ")
print("You entered: ",num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-cac8623b74d5> in <cell line: 1>()
# ----> 1 num = input("Enter a number: ")
#       2 print("You entered: ",num)
#
# TypeError: 'int' object is not callable

# %%
initial_value = 100
anual_return_rate = 0.1
years = 7

Future_value = initial_value * (1 + anual_return_rate) ** years

print("After {} years the investment of {} will be {}".format(years, initial_value, Future_value))
# Out:
# After 7 years the investment of 100 will be 194.87171000000012

# %%
a = 10
b = 5

a += b
print(a)
# Out:
# 15

# %%
a = 10
b = 5

a -= b
print(a)
# Out:
# 5

# %%
a = 10
b = 5

a *= b
print(a)
# Out:
# 50

# %%
a = 10
b = 5

a **= b
print(a)
# Out:
# 100000

# %%
a = 10
b = 5

a %= b
print(a)
# Out:
# 0

# %%
a = 10
b = 5

a /= b
print(a)
# Out:
# 2.0

# %%
x = 5
y =2

print('x = y',x == y)
# Out:
# x = y False

# %%
x = 5
y =2

print('x = y',x != y)
# Out:
# x = y True

# %%
x = 5
y =2

print('x > y =',x > y)
# Out:
# x > y = True

# %%
x = 5
y =2

print('x < y =',x < y)
# Out:
# x < y = False

# %%
x = 5
y =2

print('x <= y =',x <= y)
# Out:
# x <= y = False

# %%
x = 5
y =2

print('x >= y =',x >= y)
# Out:
# x >= y = True

# %%
j = 5
k = 5

print((j > 2) and (k >= 6))
# Out:
# False

# %%
x1 = 5
y1 = 5
x2 = 'Hello'
y2 = 'hello'
x3 = [1, 2, 3]
y3 = [1, 2, 3]

print(x1 is not y1)
print(x2 is not y2)
print(x3 is y3)
# Out:
# False
# True
# False

# %%
message = 'Hello world'
dict1 = {1:'a', 2:'b'}

print('H'in message)
print('hello'in message)
print(1 in dict1)
print('a' in dict1)
# Out:
# True
# False
# True
# False
